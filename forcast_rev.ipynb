# %%
import pandas as pd
data_ori = pd.read_csv("data/ABDforecastORI.csv")
data_ori.head()
# Out:
#     No  Komoditas (Rp) 02/ 01/ 2023 03/ 01/ 2023 04/ 01/ 2023 05/ 01/ 2023  \
# 0    I  Semua Provinsi       30,800       30,750       30,650       30,650
# 1   II            Aceh       31,950       31,950       31,950       31,950
# 2  III  Sumatera Utara       31,300       31,300       31,250       31,500
# 3   IV  Sumatera Barat       28,800       28,800       28,800       28,800
# 4    V            Riau       30,900       30,900       30,900       30,050
#
#   06/ 01/ 2023 09/ 01/ 2023 10/ 01/ 2023 11/ 01/ 2023  ... 11/ 11/ 2024  \
# 0       30,700       30,600       30,550       30,500  ...       29,350
# 1       31,950       31,800       31,900       31,850  ...       28,400
# 2       32,300       32,550       32,550       32,350  ...       30,450
# 3       28,800       28,800       28,800       28,800  ...       28,150
# 4       30,050       29,550       29,550       29,550  ...       27,750
#
#   12/ 11/ 2024 13/ 11/ 2024 14/ 11/ 2024 15/ 11/ 2024 18/ 11/ 2024  \
# ...

# %%
data_cast = pd.read_csv("data/Formatted_Forecasting_Data.csv")
data_cast.head()
# Out:
#    No  Komoditas (Rp)  02/ 01/ 2023  03/ 01/ 2023  04/ 01/ 2023  05/ 01/ 2023  \
# 0   1  Semua Provinsi       30800.0       30750.0       30650.0       30650.0
# 1   2            Aceh       31950.0       31950.0       31950.0       31950.0
# 2   3  Sumatera Utara       31300.0       31300.0       31250.0       31500.0
# 3   4  Sumatera Barat       28800.0       28800.0       28800.0       28800.0
# 4   5            Riau       30900.0       30900.0       30900.0       30050.0
#
#    06/ 01/ 2023  09/ 01/ 2023  10/ 01/ 2023  11/ 01/ 2023  ...  22/ 12/ 2025  \
# 0       30700.0       30600.0       30550.0       30500.0  ...  30094.552256
# 1       31950.0       31800.0       31900.0       31850.0  ...  28057.409233
# 2       32300.0       32550.0       32550.0       32350.0  ...  28813.560979
# 3       28800.0       28800.0       28800.0       28800.0  ...  28660.085747
# 4       30050.0       29550.0       29550.0       29550.0  ...  28233.781112
#
# ...

# %%
# Menghapus kolom yang berhubungan dengan tahun 2025
data_cast = data_cast.loc[:, ~data_cast.columns.str.contains('2025')]

# Menyimpan file yang telah diperbarui
data_cast.to_csv('data/forecast_data.csv', index=False)

# %%
data_new = pd.read_csv('data/forecast_data.csv')

data_new.head()
# Out:
#    No  Komoditas (Rp)  02/ 01/ 2023  03/ 01/ 2023  04/ 01/ 2023  05/ 01/ 2023  \
# 0   1  Semua Provinsi       30800.0       30750.0       30650.0       30650.0
# 1   2            Aceh       31950.0       31950.0       31950.0       31950.0
# 2   3  Sumatera Utara       31300.0       31300.0       31250.0       31500.0
# 3   4  Sumatera Barat       28800.0       28800.0       28800.0       28800.0
# 4   5            Riau       30900.0       30900.0       30900.0       30050.0
#
#    06/ 01/ 2023  09/ 01/ 2023  10/ 01/ 2023  11/ 01/ 2023  ...  22/ 12/ 2024  \
# 0       30700.0       30600.0       30550.0       30500.0  ...  30169.396388
# 1       31950.0       31800.0       31900.0       31850.0  ...  28764.574333
# 2       32300.0       32550.0       32550.0       32350.0  ...  29342.440046
# 3       28800.0       28800.0       28800.0       28800.0  ...  28408.629799
# 4       30050.0       29550.0       29550.0       29550.0  ...  28383.022890
#
# ...
